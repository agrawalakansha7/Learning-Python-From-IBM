# %%
#integer
11
# Out:
# 11

# %%
#float
12.76
# Out:
# 12.76

# %%
#string
"hello python"
# Out:
# 'hello python'

# %%
#to find the type
type(12)
# Out:
# int

# %%
type(12.0)
# Out:
# float

# %%
type(16.65)
# Out:
# float

# %%
type("hello akansha")
# Out:
# str

# %%
#system settings about float type
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
#to convert one type into another
float(2)
# Out:
# 2.0

# %%
type(float(2)) #to check the type
# Out:
# float

# %%
int(4.76) #this will result in loss of information
# Out:
# 4

# %%
int('1')
# Out:
# 1

# %%
int('1 or 2 people') #will result in error as int type will only require a numeric string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int('1 or 2 people') #will result in error as int type will only require a numeric string
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
float('1.2')
# Out:
# 1.2

# %%
str('1')
# Out:
# '1'

# %%
str("5.767")
# Out:
# '5.767'

# %%
#boolean type data
True
False #must use the uppercase T or F in boolean
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
int(True) #1
# Out:
# 1

# %%
bool(1) #True
# Out:
# True

# %%
bool (0)
# Out:
# False

# %%
float(True)
# Out:
# 1.0

# %%
#exercises
type(6/2) #float
# Out:
# float

# %%
type(6//2) #int, as double slashes stands fot integer division
# Out:
# int

# %%
type ("hello"=="world") #bool
# Out:
# bool

# %%
int("1001")
# Out:
# 1001

# %%
float("675.8675")
# Out:
# 675.8675
